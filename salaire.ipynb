# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
f = pd.read_csv("s.csv", error_bad_lines=False)

# %%
f
# Out:
#                                                  type  deuxonze  deuxdouze  \
# 0                                                 NaN       NaN        NaN
# 1                                                 NaN       NaN        NaN
# 2   All industries excluding unclassified enterprises     21.74      22.26
# 3                       Forestry, logging and support     24.50      24.54
# 4                   Mining and oil and gas extraction     35.07      37.80
# 5                                           Utilities       NaN        NaN
# 6                                        Construction     28.26      29.02
# 7                                       Manufacturing     22.60      23.25
# 8                                     Wholesale trade     21.06      21.49
# 9                                        Retail trade     15.51      15.79
# 10                     Transportation and warehousing     22.58      23.18
# ...

# %%
f.deuxquinze.median()
# Out:
# 24.25

# %%
f.deuxquinze.min()
# Out:
# 13.869999999999999

# %%
f.groupby("type").deuxquinze.sum().sort_values(ascending=False)
# Out:
# type
# Mining and oil and gas extraction                                                                                                                                                                                                                                39.44
# Construction                                                                                                                                                                                                                                                     30.94
# Professional, scientific and technical services                                                                                                                                                                                                                  29.14
# ...

# %%
f.groupby("type").deuxquinze.sum().sort_values().plot(kind="pie")

# %%
f.groupby("type").deuxquinze.sum().plot(kind="barh")

# %%
resto = f.type == "Accommodation and food services"
f[resto].deuxquinze.value_counts()
# Out:
# 13.87    1
# Name: deuxquinze, dtype: int64

# %%
resto = f.type == "Accommodation and food services"
